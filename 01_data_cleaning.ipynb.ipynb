# %%
import pandas as pd
import numpy as np

# %%
df_t2=pd.read_excel('Book1_with_column_names.xlsx')

# %%
df_t2.head()
# Out:
#    Run_ID (SRR) BioSample_ID (SAMN)           Age       Read_Length  \
# 0             2          SRR2080095  SAMN03784590           3-month
# 1             3          SRR2080096  SAMN03784593           3-month
# 2             4          SRR2080097  SAMN03784594           2 weeks
# 3             5          SRR2080098  SAMN03784591  12 and 60-yr-old
# 4             6          SRR2080099  SAMN03784592  12 and 60-yr-old
#
#    Total_Reads Total_Bases Institution  \
# 0          202      3.63 G     2.42 Gb
# 1          202      3.28 G     2.20 Gb
# 2          202      3.81 G     2.56 Gb
# 3          200     14.42 G     9.68 Gb
# 4          201     13.51 G     8.95 Gb
#
#                                  Developmental_Stage Experiment_ID (SRX)  \
# 0  UNIVERSITY OF SAO PAULO - LUIZ DE QUEIROZ COLLEGE        Young plants
# 1  UNIVERSITY OF SAO PAULO - LUIZ DE QUEIROZ COLLEGE        Young plants
# 2  UNIVERSITY OF SAO PAULO - LUIZ DE QUEIROZ COLLEGE            Seedling
# ...

# %%
df_t2.isnull().sum().sum()
# Out:
# 85

# %%
df_t2.isnull().sum()[df_t2.isnull().sum()>0]
# Out:
# hermaphrodite     2
# Unnamed: 15      19
# ILLUMINA         14
# SAMN03784589     14
# Unnamed: 18      19
# Unnamed: 19      17
# dtype: int64

# %%
df_t2=df_t2.replace(["","NA","N/A","null","None","na","NAN"],
                    np.nan)

# %%
df_t2
# Out:
#     Run_ID (SRR) BioSample_ID (SAMN)           Age       Read_Length  \
# 0              2          SRR2080095  SAMN03784590           3-month
# 1              3          SRR2080096  SAMN03784593           3-month
# 2              4          SRR2080097  SAMN03784594           2 weeks
# 3              5          SRR2080098  SAMN03784591  12 and 60-yr-old
# 4              6          SRR2080099  SAMN03784592  12 and 60-yr-old
# 5              7          SRR2080127  SAMN03784591  12 and 60-yr-old
# 6              8          SRR2080128  SAMN03784591  12 and 60-yr-old
# 7              9          SRR2080131  SAMN03784591  12 and 60-yr-old
# 8             10          SRR2080132  SAMN03784591  12 and 60-yr-old
# 9             11          SRR2080137  SAMN03784591  12 and 60-yr-old
# 10            12          SRR2080138  SAMN03784591  12 and 60-yr-old
# 11            13          SRR2080148  SAMN03784592  12 and 60-yr-old
# 12            14          SRR2080149  SAMN03784592  12 and 60-yr-old
# ...

# %%
df_t2.isnull().sum().sum() # total missing values
# Out:
# 85

# %%
df_t2.isna().sum().sum() # total nan values
# Out:
# 85

# %%
df_t2.to_excel("edited_bookfilefile3.xlsx",index=True)

# %%
df_t2
# Out:
#     Run_ID (SRR) BioSample_ID (SAMN)           Age       Read_Length  \
# 0              2          SRR2080095  SAMN03784590           3-month
# 1              3          SRR2080096  SAMN03784593           3-month
# 2              4          SRR2080097  SAMN03784594           2 weeks
# 3              5          SRR2080098  SAMN03784591  12 and 60-yr-old
# 4              6          SRR2080099  SAMN03784592  12 and 60-yr-old
# 5              7          SRR2080127  SAMN03784591  12 and 60-yr-old
# 6              8          SRR2080128  SAMN03784591  12 and 60-yr-old
# 7              9          SRR2080131  SAMN03784591  12 and 60-yr-old
# 8             10          SRR2080132  SAMN03784591  12 and 60-yr-old
# 9             11          SRR2080137  SAMN03784591  12 and 60-yr-old
# 10            12          SRR2080138  SAMN03784591  12 and 60-yr-old
# 11            13          SRR2080148  SAMN03784592  12 and 60-yr-old
# 12            14          SRR2080149  SAMN03784592  12 and 60-yr-old
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SWARA LAKSHMI J\\PROJECT ML 1'
